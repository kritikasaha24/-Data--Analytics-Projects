# %% [markdown]
# ## Openweathermap.org API

# %%
#importing the libraries
import requests
import json

# %%
# API endpoint and key
api_key = '68a7cd6a78bb43b7803e9bab558b0a88'  # Replace with your valid API key
city = 'Bengaluru'
url = f'http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}'

# %%
#get request to get a response from the server
response =  requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
#extracting only the json data from the response object
data = response.json()

# %%
data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1740452400,
#    'main': {'temp': 291.23,
#     'feels_like': 290.97,
#     'temp_min': 291.23,
#     'temp_max': 293.75,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 920,
#     'humidity': 72,
#     'temp_kf': -2.52},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 29},
#    'wind': {'speed': 4.84, 'deg': 90, 'gust': 7.61},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-02-25 03:00:00'},
#   {'dt': 1740463200,
#    'main': {'temp': 296.9,
#     'feels_like': 296.48,
#     'temp_min': 296.9,
#     'temp_max': 300.37,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 920,
#     'humidity': 44,
#     'temp_kf': -3.47},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
# ...

# %%
#accessing the json elements like a dictionary
data['cnt']
# Out:
# 40

# %%
data['list'][0]['main']
# Out:
# {'temp': 291.23,
#  'feels_like': 290.97,
#  'temp_min': 291.23,
#  'temp_max': 293.75,
#  'pressure': 1017,
#  'sea_level': 1017,
#  'grnd_level': 920,
#  'humidity': 72,
#  'temp_kf': -2.52}

# %%
round(data['list'][0]['main']['temp_min'] - 273.15)
# Out:
# 18

# %%
import requests
import json

# Taking user input to show weather details of any city
city_name = input('Enter the city name: ')
api_key = '68a7cd6a78bb43b7803e9bab558b0a88'
url2 = f'https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={api_key}'

response2 = requests.get(url2)
data2 = response2.json()

if response2.status_code == 200:
    print('Weather:', data2['weather'][0]['main'])
    print('City:', data2['name'])
    print('Temperature:', round(data2['main']['temp'] - 273.15), '°C')
else:
    print("Enter the correct city please")
# Out:
# Enter the city name:  jaipur
# Weather: Haze
# City: Jaipur
# Temperature: 21 °C

# %%
# !pip install python-dotenv

# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
API_KEY = os.getenv('API_KEY')

# %%
import requests
import json

# API Key
API_KEY = '68a7cd6a78bb43b7803e9bab558b0a88'

# Taking user input to show weather details of any city
city_name = input('Enter the city name: ')
url2 = 'https://api.openweathermap.org/data/2.5/weather?q=' + city_name + '&appid=' + API_KEY

response2 = requests.get(url2)
data2 = response2.json()

if response2.status_code == 200:
    print('Weather:', data2['weather'][0]['main'])
    print('City:', data2['name'])
    print('Temperature:', round(data2['main']['temp'] - 273.15), '°C')
else:
    print("Enter the correct city please")
# Out:
# Enter the city name: jaipur
# Weather: Haze
# City: Jaipur
# Temperature: 17 °C
